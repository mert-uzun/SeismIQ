# %%
import re
import csv

# %%
import re
import csv

# regex patterns
hashtag_pat = re.compile(r"#\S+")
non_tr_pat = re.compile(r"[^a-zA-ZçÇğĞıİöÖşŞüÜÂâÎîÛû0-9\s]")
url_pat = re.compile(r"https?://\S+|www\.\S+")
all_letters = "A-Za-zÇĞİIÖŞÜçğıöşü"
tr_vowels = "AaEeIıİiOoÖöUuÜü"

# banned keywords/phrases
banned_keywords = [
    "suriyeli", "allah aşk", "allah ra", "allah yar", "allahtan",
    "uygulama", "vpn", "tl", "iban", "dolar", "euro",
    "rabbim", "ücretsiz", "ucretsiz", "hz", "orospu",
    "neredeyim", "büyüklü", "vur emr", "şükür", "şifalar",
    "maddi destek", "şiddet", "allah ım", "geçmiş olsun", "allahım", "inşallah"
    "turkcell","vodafone","turk telekom","turktelekom","allahim"
]

def remove_hashtags(text: str):
    return hashtag_pat.sub("", text).strip()

url_pattern = re.compile(r'https?://\S+|www\.\S+')

def remove_links(text: str) -> str:
    return url_pattern.sub('', text)

def to_lower(text: str):
    return text.lower()

def remove_non_unicode(text: str):
    return non_tr_pat.sub("", text)


def collapse_elongations(text: str, max_run: int = 2, vowels_only: bool = False):
    if max_run < 1:
        max_run = 1
    cls = tr_vowels if vowels_only else all_letters
    pattern = re.compile(rf"([{cls}])\1{{{max_run},}}", re.UNICODE)
    return pattern.sub(lambda m: m.group(1) * max_run, text)

def word_count_filter(text: str, min_words: int = 3) -> bool:
    return len(text.strip().split()) > min_words

def remove_keywords(text: str):
    lowered = text.lower()
    for kw in banned_keywords:
        if kw in lowered:
            return ""   # drop tweet completely
    return text

# zemberek + fallback analyzers
try:
    from zemberek.normalization import NoisyTextNormalizer
    z_normalizer = NoisyTextNormalizer()
except Exception:
    z_normalizer = None

z_morph = None
try:
    from zemberek.morphology import TurkishMorphology
    z_morph = TurkishMorphology()
except Exception:
    z_morph = None

z_zeyrek = None
try:
    import zeyrek
    z_zeyrek = zeyrek.MorphAnalyzer()
except Exception:
    z_zeyrek = None

def normalize_text(text: str):
    if z_normalizer is None:
        return text
    try:
        return z_normalizer.normalize(text)
    except Exception:
        return text

def lemmatize_text(text: str):
    tokens = text.split()
    if z_morph is not None:
        lemmas = []
        for tok in tokens:
            try:
                analyses = z_morph.analyze(tok)
                if analyses:
                    lemmas.append(analyses[0].lemma)
                else:
                    lemmas.append(tok)
            except Exception:
                lemmas.append(tok)
        return " ".join(lemmas)
    if z_zeyrek is not None:
        try:
            pairs = z_zeyrek.lemmatize(text)
            return " ".join((lemmas[0] if lemmas else w) for (w, lemmas) in pairs)
        except Exception:
            return text
    return text

def clean_tweet(text: str, use_normalizer: bool = True, min_words: int = 3):
    text = remove_links(text)
    text = remove_hashtags(text)
    text = to_lower(text)
    text = remove_non_unicode(text)
    text = collapse_elongations(text, max_run=2)

    if not word_count_filter(text, min_words=min_words):
        return ""

    if use_normalizer:
        text = normalize_text(text)

    text = lemmatize_text(text)
    text = re.sub(r"\s+", " ", text).strip()

    # drop tweet if banned keyword present
    text = remove_keywords(text)

    return text

# %%
if __name__ == "__main__":
    input_csv = "Aug10_earthquake_tweets.csv"
    column_name = "text"

    with open(input_csv, mode="r", encoding="utf-8", newline="") as infile:
        reader = csv.DictReader(infile)
        shown = 0
        for row in reader:
            raw_text = row.get(column_name, "")
            if not raw_text:
                continue
            cleaned_text = clean_tweet(raw_text, use_normalizer=True, min_words=3)
            if cleaned_text:
                print(cleaned_text)
                shown += 1
            if shown >= 200:
                break
# Out:
# balıkesir 61 derinlik 11 km
# ankara da deprem mi oldu yoksa biz yanlış mı hissettik
# baya bir saklandık beşik gibi kuşumu alıp çıktım altınlar aklıma gelmedi bile yani arkadaşlar mal değil can önemli olan
# balıkesir sındırgıda 61 olmuş dünden beri 34 civarında oluyordu de ek kir öncüymüş bunlar allah beterinden korusun
# oldu balıkesirde yaşam vatandaşlar iyi misiniz
# biz boşa mı her ay binlerce fatura ödüyoruz amk şaka gibi istanbul üssü olsa deprem hat tamamen gidecek herhalde
# eskişehirde çok kötü hissettik yaa
# depremi hisseden tek ben olamam
# deprem esnasında ne yapıyordunuz
# 15 20 saniye sürdü ne hissettik öyle birden
# cok gecmis olsun bursada feci sallandık
# hissetmedim ama herkese gecmis olsun
# balıkesir de ki 62 lik deprem de doğal bir deprem değil büyük marmara depremi olmayacak bu depremler birilerine mesaj korkmayın
# yataktan fırlattı cidden 15 saniye kadar sürdü hiç bu kadar hissetmemiştim iyi misiniz
# manisa kırkağaç bostancı mahallesi çok kötü sallandık
# kütahyada çok fena hissettik
# istanbul izmir bursada da hissedilmis cok gecmis olsun umarim hasar ve can kaybi yoktur
# 62 deprem meydana gelmis
# elim ayağım boşaldı lan
# istanbulda çok fena hissettik
# olmuş hiç hissetmedim bildirim de depremden 5 dakika sonra geldi
# subhanallah vantilatör sağ sol gitti geldi
# istanbulda hissedilen meydana geldi
# ciddi manada hissettiğim 2
# bursadan çok net hissedildi allah korusun
# çok uzun süre sallandık 57 diyorlar
# acaba sırf dünya için mi yaratılmışsın ki bütün vaktini ona sarf ediyorsun risalei nurdan
# deprem bütün ege marmara civarında hissedilmiş merkezi balıkesir diyorlar ama bilgisi olan var mı
# yine deprem oldu allah belanı versin yalı kazığı ali koç istifa et artık lan
# olmuş allah beterinden korusun umarım can kaybı yoktur
# androidler cayır cuyur bildirimde yine bizim apple ların konudan haberi yok aq
# balıkesir sındırgı kandilli rasathanesi 61 korkunç sallandık
# uzun surdu salladikca salladi
# çok fena sallandık gecmiş olsun herkese
# binalardan yapılardan uzak durun
# deprem oldu hisseden var mı ben şöyle bir bildirimle sarsıldım da
# izmirden istanbula gidiyoruzçok kötü sallandık
# yeniden deprem olucak diyorlar doğrumu
# eskişehir böyle sallandıysa merkez üssü nasıl sallanmıştır
# inanilmaz kotu deprem oluyor eskisehirde bile hissedildi
# deprem oldu telefonlar pert oldu allah belanızı versin haram zıkkım olsun
# allah muhafaza eylesin tekirdağ da baya hissedildi
# deprem oldu balıkesir merkezli
# rakı içerken depreme yakalananlar burdamı
# nasıl salladı böyle çok fenaydı
# balikesir merkez ussu 61 buyuklugunde guncellendi istanbul anadolu yakasi ve egenin buyuk bolumunde hissedildi
# 61 balıkesirsındırgı dilerim can kaybımız yoktur
# 61 den çok fazlaydı bu arada
# deprem sonrası operatörlerde bağlantı problemleri yaşanıyor
# deprem oldu tedbirinizi alın sakin kalın panik en büyük ikinci felakettir fena sallandı
# android sisteme yine deprem bilgisi geldi erkenden
# fena sallandık sakarya da inanılmaz hissettik
# merkez üssü neresidir onu bilmiyorum araştırdım ama yoğunluktan bulamadım manisa şehir hastanesinin bahçesinde ameliyat saatini beklerken birde bu geldi başımıza allah beterinden saklasın
# off aynı 17 ağustos gibi oldu
# android bildirim yolladı 20 saniye sonra hissettik sakaryada
# çok kötü depremle sallandık herkes iyidir inşallah
# deprem oldu hisseden var mı
# depremden önce uyarı geldi
# telefona bildirim geldi ve 5 saniye sonra sallandık
# nasıl bir sallanmaydi o heryerden ses geldi
# umarım hiç kimsede birşey yoktur
# felaket salladı ne yapacağımı şaşırdım evde tek başıma allah beterinden korusun
# balıkesir 61 allah beterinden korusun
# aman allah korusun sıkıntı yoktur inşallah
# istanbul başakşehir de oturuyorum ilk defa depremi hissettim normalde burada deprem pek hissedilmez
# edremit körfezi çok fena sallandı
# balikesirde olan depremde ankarada sallandı
# baya sallandık allah beterini yaşatmasın
# 61 diyorlar deprem bir şey yoktur inşallah
# umarım can ve mal kaybı olmamıştır
# androide 20 saniye önce deprem olacak bildirimi geldi hayat kurtarır
# ailendeki herkes o şehirdedir ve senden uzaktadırlar
# arkadaşa diyom deprem oldu 1 saat sonra yazıyo afaddan teyit ediyor herhalde aw
# bodrumda hissettik epey sarsıcıydı
# çok hafif ankaradan hissedildi
# derinden salladı merkez üssü neresi ise oradakikere allah kolaylık versin burada böyle hissedildiyse
# twitter dan teyit için herkes bakıyor
# benim şansıma ne kadar istanbula gelmeye niyet etsem deprem oluyor beni mi istemiyor anlamadım
# fena salladı izmiridenizin ortasındayız aman gözünü seveyim
# tekirdagda deprem oldu hisseden var mi
# o ne bicim depremdi oyle
# allah beterinden kurusun inşaallah bir çok ilden hissedilmiş
# başım dönmemiş oldu kadıköy erenköy
# bu artçı depremler bitti derken çevre illerden gelen depremi hissediyoruz
# cok kötü sallandı ilk defa öleceğimi düşündüm
# afyonda hissedildi ve yine aynı korku
# balıkesir sındırğı 61 allah korusun
# birkaç saniye önce gelen deprem uyarısı sonrası sallanmaya başlanmam
# istanbulda oldu ben yine bekliyorum yıkıcı olmamak ile beraber bir sarsıntı daha gelir
# lan beşik gibi bi başladı durmuyo allah korusun dikkat edin
# istanbulda çok hissedildi mi
# tekrar salladı artcılar sürüyor evlerden uzak duralım
# iyi sallandık çınarcık bigadiç 62
# kocaeli hissedildi 45 saniye sürdü
# çok geçmiş olsjn umarım kimseye zarar gelmemiştir
# ulan yazıklar olsun allah belanızı versin 61 lik depremde bile telefon ve internet cekmiyo onca para alıyorsunuz bide yazıklar olsun
# allah beterinden korusun çok fena sallandık
# nasıl yani türkiyenin yarısı mı sallandı yalovada fena hissedildi
# balıkesir sındırgı deprem 61 umarım can kaybı yoktur
# çok kötü çok kötü hala titriyorum
# o neydi öyle ya yer şangır şungur sallanırken gök gürültüsü gibi bi uğultu geldi ayakta bi sağa bi sola yalpaladım
# oldu benim istanbuldaki evim beşik gibi sallandı sorsan sağlam bina bir daha deprem olursa ne hale gelir allah bilir
# olduğunu inandıramadım ekrandan izleyene kadar
# hayatımızın her anı aksiyon hiçbirsey olmazsa bile deprem koyuyor ansızın
# bursada aşırı hissedildi uzun sürdü baya
# balıkesirde 62 büyükküğünde deprem olmuşinşallah yıkılan bina yoktur
# geçen zamanı rahat olun demiştim bu sefer yorum yapmayacam zamanını bilemiyorum çünkü
# deprem ülkesinde yaşıyoruz her an her şey olabilir deprem vergilerinle yol yaptık diyenler yol yapmaya pardon çalmaya devam etsin
# balıkesir iyi misin ses ver afyon da güzel sallandık rabbım korusun
# manisa akhisar çok kötü hissettik
# iyi salladı allah beterinden saklasın
# boludan da hissettik allah beterinden korusun
# şanliurfada madde bağimliliği faciasi baba oğlunu silahla vurdu urfa çalişma grubu kapsamli mücadele çağrisi yapti
# balikesir sındırgı merkezli 62 pek çok ilde hissedildi
# istanbulda hissedilen deprem meydana geldi
# bu gece yine uyku yok sanırım
# istanbuldayım çok fena salladı
# izmire ne zaman gelsem deprem oluyor
# dehşet sallandık tarifsiz korku
# telefonuma bildirim geldi direkt giyindim iki sn sonra oldu
# telefona uyarı geldikten bir dakka içinde oldu
# mekanın sahibi yine kendini hatırlattı
# çok hissettim bu sefer
# aydındayım hissettik depremi allah korusun
# uyarı sistemi depremden sonra uyarı veriyor nasıl bir sistem anlamadım
# evdekileri deprem olduğuna inandıramadım
# bu nasıl bir sallanmadır
# arkadaşlar nasıldı herkes iyidir umarım bilgi verin
# manisada neye uğradığımızı şaşırdık
# yine yokladı aq şerefsizi
# istanbul anadolu yakası depremi hisseden var mı
# deprem olmuştur ve o sırada ne kandillinin ne de afad in sitesine ulasilamiyordur
# erdekde beşik gibi sallandık inşallah can kaybı yoktur
# uzun süre sonra ilk defa bu kadar sallandık
# izmirde oldu ve bu kez telefona önceden uyarı gelmedi depremden yaklaşık 2 dk sonra uyarı geldi
# duştaydım olmuş var mı hisseden
# bodrumda bile hisseldi önce alkolün etkisiyle beynim sallanıyor sandım
# olm çok uzun sürdü laa
# ödüm bokuma karıştı aq
# çok az hissettik istanbulda ardçısı olur mu sokağa inelim mi
# turkcell yine elin götün karıştı tel çekmez internet çekmez hayvan gibi fatura ödüyoruz haram zıkkım olsun
# çok kötü sallandık 62
# balıkesirde olmuş teyzemler evden çıkmış dışarı
# de hissettim kandilli rasathanesine giremiyorum
# istanbul beşik gibi sallandı ama ne kandilliinfo den ne de depremdairesi nden hala ses soluk yok
# çok fena salladıı çok korktumm
# 62 balıkesir de olmuş
# bu nasıl deprem yahu neredeyse türkiye sallanmış
# yangın derken cehdetmiş gibi
# deprem olduğuna dair iddaalar var ben zaten anlamıyorum iyi ki varsın twitter
# balikesir merkezli 62 yüzeye çok yakın oldu sanırım ülkenin batısı komple hissetmiş
# nerede oldu bilmiyorum ama balıkesir de teyzemin dolaplar da kırılmadık eşya kalmamış
# nerede oldu bu deprem kütahya fena sallandı
# deprem oldu 61 balıkesir sındırgı
# tek seferlik şap diye vurdu geçti allah cc beterinden korusun fena salladı
# merkez üssü balıkesir sındırgı 62 deniyor
# uşakta da hissettik hâlâ sallanıyor gibiyim
# deprem oldu ben hissetmedim ne oluyo laan
# çok büyük deprem oldu allah cc korusun inşallah
# çok geçmiş inşallah herkes iyidir
# yaklaşık 1015 sn arası sürmüştür sanırım bu zaman zarfı içinde 62 değil de biraz daha büyük olsa allah korusun kötü sonuçlara yol açabilirdi
# iyi salladı sancaktepe çekmeköy
# hissettiği halde deprem olduğuna emin emin olmak için twittera girenler burada mı
# android 57 bekleniyor bildirimi atti en az 5 saniye içinde de sallanmaya basladik uyarilari acin
# ilk defa deprem bildirimi geldi geldiği gibi deprem oldu
# gecmis olsun balikesir umarim can kaybi yasanmaz
# şimdi olmuş biri geldi abla hissetmedin mi diyor neyi diyorum depremi diyor otururken bile hissetmedim kesin ufacık bir şey oldu
# önce bildirim geldi geldiği gibi depremde oldu
# istanbul yine sallandı allah sonumuzu hayır etsin
# izmir den istanbul a kadar en az 10 ilde hissedilen bir deprem meydana geldi ilk bilgi 61
# bursa da deprem meydana geldi ciddi anlamda uğultu halinde seslerle hissettik
# cok kötü deprem oldu
# manisa çok pis sallandı
# uzun zaman sonra ilk defa bu kadar uzun ve hissedilir bir sallanma yaşadım elim ayağım kesildi
# şanliurfadan ankaraya gazze için insani yürüyüş
# istanbul izmir ankara da hissedilen deprem meydana geldi
# çok fena sallandık lüleburgaz
# bu defa uzun sürdü beşik gibi salladı
# son dakika istanbuldada hissedilen depremin merkezinin balıkesir olduğu söyleniyor
# deprem burayı bu kadar salladıysa merkezine ne yapmıştır acaba kimsede zarar yoktur umarım
# vallahi hazırlıklı falan değiliz deprem e allah a emanet yaşıyoruz istanbulda bu konularda ülke olarak malasef çok çok gerideyiz
# baya sallandık yerde duran çiçek hala sallanıyor
# bursa da çok kötü sallandık hepimiz sokaktayız
# tuvallette de yakalanmazsın neye uğradığımı şaşırdım
# dedim ki yıkıldı abi oneydi yaa
# bursada korkutan çok ciddi salladı
# depremi hisseden oldumu ilk defa bildirim geldi
# haberlapsus takip et haberin olsun istanbulda izmirde balıkesirde
# tekirdağda da çok kötü sallandık allah beterinden korusun
# nereye gitsem benimle gelıyorsun
# çok salladı elim ayağım titriyor trakya kırklareli her yeri çok fena salladı
# den önce telefona üç saniye once bildirim geldi
# bursa çok fena sallandı
# altındaki sandalye sallandı depremi hissetmene rağmen hala deprem oldumu diye twitter a bakanlar burdamı
# afyon bile sallandı allah beterinden korusun
# olmus mk hic hissetmedim yaslandım iyicene
# az önce balkonda otururken sallandım oturduğum koltuk epey sallandı bu nerenin depremi
# deprem oldu çok fena sallandı
# uyarı geldi izmirde diye baktım sallanıyorum balıkesirdeymiş
# son dakika deprem 10dan fazla şehirde hissedildi ne durumdasınız
